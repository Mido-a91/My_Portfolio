# %% [markdown]
# # 3- Audiobooks business case - Data Modelling

# %% [markdown]
# ## Problem
#
# You are given data from an Audiobook app. Logically, it relates only to the audio versions of books. Each customer in the database has made a purchase at least once, that's why he/she is in the database. We want to create a machine learning algorithm based on our available data that can predict if a customer will buy again from the Audiobook company.
#
# The main idea is that if a customer has a low probability of coming back, there is no reason to spend any money on advertizing to him/her. If we can focus our efforts ONLY on customers that are likely to convert again, we can make great savings. Moreover, this model can identify the most important metrics for a customer to come back again. Identifying new customers creates value and growth opportunities.
#
# You have a .csv summarizing the data. There are several variables: Customer ID, Book length in mins_avg (average of all purchases), Book length in minutes_sum (sum of all purchases), Price Paid_avg (average of all purchases), Price paid_sum (sum of all purchases), Review (a Boolean variable), Review (out of 10), Total minutes listened, Completion (from 0 to 1), Support requests (number), and Last visited minus purchase date (in days).
#
# So these are the inputs (excluding customer ID, as it is completely arbitrary. It's more like a name, than a number).
#
# The targets are a Boolean variable (so 0, or 1). We are taking a period of 2 years in our inputs, and the next 6 months as targets. So, in fact, we are predicting if: based on the last 2 years of activity and engagement, a customer will convert in the next 6 months. 6 months sounds like a reasonable time. If they don't convert after 6 months, chances are they've gone to a competitor or didn't like the Audiobook way of digesting information.
#
# The task is simple: create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# This is a classification problem with two classes: won't buy and will buy, represented by 0s and 1s.

# %% [markdown]
# ## Create the machine learning algorithm

# %% [markdown]
# ### Import the relevant libraries

# %%
# we must import the libraries once again since we haven't imported them in this file
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Load Data
# - when we saved each of the Train, Validation and Test, they were saved as 2 tuples of inputs and targets
# - When loading them, we will load them as inputs and targets seperately

# %%
# let's create a temporary variable npz, where we will store each of the three Audiobooks datasets
npz = np.load('Audiobooks_data_train.npz')

# we extract the inputs using the keyword under which we saved them
# to ensure that they are all floats, let's also take care of that
train_inputs = npz['inputs'].astype(np.float)
# targets must be int because of sparse_categorical_crossentropy (we want to be able to smoothly one-hot encode them)
train_targets = npz['targets'].astype(np.int)

# we load the validation data in the temporary variable
npz = np.load('Audiobooks_data_validation.npz')
# we can load the inputs and the targets in the same line
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# we load the test data in the temporary variable
npz = np.load('Audiobooks_data_test.npz')
# we create 2 variables that will contain the test inputs and the test targets
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)
#Train Data

# %% [markdown]
# ### Model
# Outline, optimizers, loss, early stopping and training

# %%
# Set the input and output sizes
input_size = 10
output_size = 2
# Use same hidden layer size for both hidden layers. Not a necessity.
hidden_layer_size = 50
    
# define how the model will look like

model = tf.keras.Sequential([
    # tf.keras.layers.Dense is basically implementing: output = activation(dot(input, weight) + bias)
    # it takes several arguments, but the most important ones for us are the hidden_layer_size and the activation function
    # Unlike the Mnist we dont need the first layer (Flatten the matrix to vector) - We already have preprocessed inputs
    
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    # the final layer is no different, we just make sure to activate it with softmax - the output is a classifier
    tf.keras.layers.Dense(output_size, activation='softmax') # output layer
])


### Choose the optimizer and the loss function

# we define the optimizer we'd like to use, 
# the loss function, chosen as that so we have our targets one hot encoded when compared to outputs
# and the metrics we are interested in obtaining at each iteration
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

### Training
# That's where we train the model we have built.

# set the batch size
batch_size = 100

# set a maximum number of training epochs
max_epochs = 100


# fit the model
# note that this time the train, validation and test data are not iterable
# the batch size is directly done when we are fitting not using .batch
# this time unlike the MNIST which was 1 iterable 2 Tuple object, this time we have inputs and targets seperately

model.fit(train_inputs, # train inputs
          train_targets, # train targets
          batch_size=batch_size, # batch size
          epochs=max_epochs, # epochs that we will train for (assuming early stopping doesn't kick in)
          validation_data=(validation_inputs, validation_targets), # validation data
          verbose = 2 # making sure we get enough information about the training process
          )  

# We need a mechanism that we dont overfit - Notice the Validation accuracy oscillating
# We didnt care about the early stopping mechanism or overfitting since the data was well prerprocessed - but we need that
# Early stopping = Either updates too small means loss function minimized OR validation loss divergess from Training Loss 
# Whichever is first
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 0s - loss: 0.5656 - accuracy: 0.7664 - val_loss: 0.4250 - val_accuracy: 0.8770
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.3760 - accuracy: 0.8704 - val_loss: 0.3238 - val_accuracy: 0.8904
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.3222 - accuracy: 0.8807 - val_loss: 0.2965 - val_accuracy: 0.8993
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.3007 - accuracy: 0.8860 - val_loss: 0.2815 - val_accuracy: 0.9016
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.2872 - accuracy: 0.8910 - val_loss: 0.2664 - val_accuracy: 0.9016
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.2767 - accuracy: 0.8949 - val_loss: 0.2590 - val_accuracy: 0.9105
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.2721 - accuracy: 0.8975 - val_loss: 0.2506 - val_accuracy: 0.9083
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.2633 - accuracy: 0.8989 - val_loss: 0.2450 - val_accuracy: 0.9083
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.2605 - accuracy: 0.9028 - val_loss: 0.2374 - val_accuracy: 0.9128
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.2547 - accuracy: 0.9030 - val_loss: 0.2379 - val_accuracy: 0.9172
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.2534 - accuracy: 0.9025 - val_loss: 0.2357 - val_accuracy: 0.9128
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.2502 - accuracy: 0.9053 - val_loss: 0.2286 - val_accuracy: 0.9128
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.2481 - accuracy: 0.9064 - val_loss: 0.2345 - val_accuracy: 0.9083
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.2447 - accuracy: 0.9061 - val_loss: 0.2319 - val_accuracy: 0.9195
# Epoch 15/100
# 3579/3579 - 0s - loss: 0.2416 - accuracy: 0.9095 - val_loss: 0.2255 - val_accuracy: 0.9128
# Epoch 16/100
# 3579/3579 - 0s - loss: 0.2403 - accuracy: 0.9111 - val_loss: 0.2229 - val_accuracy: 0.9172
# Epoch 17/100
# 3579/3579 - 0s - loss: 0.2388 - accuracy: 0.9081 - val_loss: 0.2305 - val_accuracy: 0.9217
# Epoch 18/100
# 3579/3579 - 0s - loss: 0.2392 - accuracy: 0.9081 - val_loss: 0.2227 - val_accuracy: 0.9195
# Epoch 19/100
# 3579/3579 - 0s - loss: 0.2380 - accuracy: 0.9100 - val_loss: 0.2256 - val_accuracy: 0.9239
# Epoch 20/100
# 3579/3579 - 0s - loss: 0.2365 - accuracy: 0.9123 - val_loss: 0.2240 - val_accuracy: 0.9262
# Epoch 21/100
# 3579/3579 - 0s - loss: 0.2339 - accuracy: 0.9106 - val_loss: 0.2252 - val_accuracy: 0.9172
# Epoch 22/100
# 3579/3579 - 0s - loss: 0.2351 - accuracy: 0.9125 - val_loss: 0.2233 - val_accuracy: 0.9195
# Epoch 23/100
# 3579/3579 - 0s - loss: 0.2372 - accuracy: 0.9111 - val_loss: 0.2167 - val_accuracy: 0.9195
# Epoch 24/100
# 3579/3579 - 0s - loss: 0.2323 - accuracy: 0.9120 - val_loss: 0.2183 - val_accuracy: 0.9239
# Epoch 25/100
# 3579/3579 - 0s - loss: 0.2330 - accuracy: 0.9125 - val_loss: 0.2182 - val_accuracy: 0.9217
# Epoch 26/100
# 3579/3579 - 0s - loss: 0.2309 - accuracy: 0.9142 - val_loss: 0.2164 - val_accuracy: 0.9217
# Epoch 27/100
# 3579/3579 - 0s - loss: 0.2328 - accuracy: 0.9117 - val_loss: 0.2165 - val_accuracy: 0.9195
# Epoch 28/100
# 3579/3579 - 0s - loss: 0.2314 - accuracy: 0.9153 - val_loss: 0.2121 - val_accuracy: 0.9217
# Epoch 29/100
# 3579/3579 - 0s - loss: 0.2295 - accuracy: 0.9139 - val_loss: 0.2161 - val_accuracy: 0.9195
# Epoch 30/100
# 3579/3579 - 0s - loss: 0.2291 - accuracy: 0.9137 - val_loss: 0.2193 - val_accuracy: 0.9217
# Epoch 31/100
# 3579/3579 - 0s - loss: 0.2263 - accuracy: 0.9142 - val_loss: 0.2179 - val_accuracy: 0.9239
# Epoch 32/100
# 3579/3579 - 0s - loss: 0.2273 - accuracy: 0.9156 - val_loss: 0.2149 - val_accuracy: 0.9217
# Epoch 33/100
# 3579/3579 - 0s - loss: 0.2305 - accuracy: 0.9134 - val_loss: 0.2190 - val_accuracy: 0.9217
# Epoch 34/100
# 3579/3579 - 0s - loss: 0.2252 - accuracy: 0.9142 - val_loss: 0.2140 - val_accuracy: 0.9217
# Epoch 35/100
# 3579/3579 - 0s - loss: 0.2287 - accuracy: 0.9131 - val_loss: 0.2231 - val_accuracy: 0.9306
# Epoch 36/100
# 3579/3579 - 0s - loss: 0.2243 - accuracy: 0.9145 - val_loss: 0.2131 - val_accuracy: 0.9262
# Epoch 37/100
# 3579/3579 - 0s - loss: 0.2253 - accuracy: 0.9142 - val_loss: 0.2187 - val_accuracy: 0.9195
# Epoch 38/100
# 3579/3579 - 0s - loss: 0.2263 - accuracy: 0.9131 - val_loss: 0.2195 - val_accuracy: 0.9239
# Epoch 39/100
# 3579/3579 - 0s - loss: 0.2246 - accuracy: 0.9145 - val_loss: 0.2230 - val_accuracy: 0.9262
# Epoch 40/100
# 3579/3579 - 0s - loss: 0.2228 - accuracy: 0.9142 - val_loss: 0.2128 - val_accuracy: 0.9239
# Epoch 41/100
# 3579/3579 - 0s - loss: 0.2263 - accuracy: 0.9176 - val_loss: 0.2207 - val_accuracy: 0.9284
# Epoch 42/100
# 3579/3579 - 0s - loss: 0.2228 - accuracy: 0.9162 - val_loss: 0.2152 - val_accuracy: 0.9284
# Epoch 43/100
# 3579/3579 - 0s - loss: 0.2230 - accuracy: 0.9165 - val_loss: 0.2146 - val_accuracy: 0.9284
# Epoch 44/100
# 3579/3579 - 0s - loss: 0.2243 - accuracy: 0.9167 - val_loss: 0.2162 - val_accuracy: 0.9172
# Epoch 45/100
# 3579/3579 - 0s - loss: 0.2224 - accuracy: 0.9173 - val_loss: 0.2147 - val_accuracy: 0.9239
# Epoch 46/100
# 3579/3579 - 0s - loss: 0.2241 - accuracy: 0.9151 - val_loss: 0.2177 - val_accuracy: 0.9239
# Epoch 47/100
# 3579/3579 - 0s - loss: 0.2215 - accuracy: 0.9156 - val_loss: 0.2171 - val_accuracy: 0.9306
# Epoch 48/100
# 3579/3579 - 0s - loss: 0.2216 - accuracy: 0.9148 - val_loss: 0.2193 - val_accuracy: 0.9262
# Epoch 49/100
# 3579/3579 - 0s - loss: 0.2207 - accuracy: 0.9170 - val_loss: 0.2118 - val_accuracy: 0.9262
# Epoch 50/100
# 3579/3579 - 0s - loss: 0.2220 - accuracy: 0.9167 - val_loss: 0.2275 - val_accuracy: 0.9262
# Epoch 51/100
# 3579/3579 - 0s - loss: 0.2215 - accuracy: 0.9165 - val_loss: 0.2197 - val_accuracy: 0.9262
# Epoch 52/100
# 3579/3579 - 0s - loss: 0.2184 - accuracy: 0.9184 - val_loss: 0.2124 - val_accuracy: 0.9172
# Epoch 53/100
# 3579/3579 - 0s - loss: 0.2214 - accuracy: 0.9181 - val_loss: 0.2119 - val_accuracy: 0.9217
# Epoch 54/100
# 3579/3579 - 0s - loss: 0.2180 - accuracy: 0.9181 - val_loss: 0.2125 - val_accuracy: 0.9284
# Epoch 55/100
# 3579/3579 - 0s - loss: 0.2173 - accuracy: 0.9195 - val_loss: 0.2133 - val_accuracy: 0.9217
# Epoch 56/100
# 3579/3579 - 0s - loss: 0.2206 - accuracy: 0.9176 - val_loss: 0.2172 - val_accuracy: 0.9217
# Epoch 57/100
# 3579/3579 - 0s - loss: 0.2200 - accuracy: 0.9176 - val_loss: 0.2349 - val_accuracy: 0.9262
# Epoch 58/100
# 3579/3579 - 0s - loss: 0.2209 - accuracy: 0.9156 - val_loss: 0.2267 - val_accuracy: 0.9262
# Epoch 59/100
# 3579/3579 - 0s - loss: 0.2181 - accuracy: 0.9190 - val_loss: 0.2098 - val_accuracy: 0.9284
# Epoch 60/100
# 3579/3579 - 0s - loss: 0.2176 - accuracy: 0.9190 - val_loss: 0.2101 - val_accuracy: 0.9284
# Epoch 61/100
# 3579/3579 - 0s - loss: 0.2241 - accuracy: 0.9170 - val_loss: 0.2193 - val_accuracy: 0.9239
# Epoch 62/100
# 3579/3579 - 0s - loss: 0.2214 - accuracy: 0.9173 - val_loss: 0.2152 - val_accuracy: 0.9262
# Epoch 63/100
# 3579/3579 - 0s - loss: 0.2198 - accuracy: 0.9159 - val_loss: 0.2158 - val_accuracy: 0.9284
# Epoch 64/100
# 3579/3579 - 0s - loss: 0.2150 - accuracy: 0.9198 - val_loss: 0.2151 - val_accuracy: 0.9262
# Epoch 65/100
# 3579/3579 - 0s - loss: 0.2172 - accuracy: 0.9193 - val_loss: 0.2282 - val_accuracy: 0.9262
# Epoch 66/100
# 3579/3579 - 0s - loss: 0.2198 - accuracy: 0.9167 - val_loss: 0.2133 - val_accuracy: 0.9262
# Epoch 67/100
# 3579/3579 - 0s - loss: 0.2165 - accuracy: 0.9190 - val_loss: 0.2149 - val_accuracy: 0.9195
# Epoch 68/100
# 3579/3579 - 0s - loss: 0.2155 - accuracy: 0.9193 - val_loss: 0.2302 - val_accuracy: 0.9239
# Epoch 69/100
# 3579/3579 - 0s - loss: 0.2157 - accuracy: 0.9184 - val_loss: 0.2133 - val_accuracy: 0.9284
# Epoch 70/100
# 3579/3579 - 0s - loss: 0.2171 - accuracy: 0.9204 - val_loss: 0.2188 - val_accuracy: 0.9262
# Epoch 71/100
# 3579/3579 - 0s - loss: 0.2181 - accuracy: 0.9173 - val_loss: 0.2224 - val_accuracy: 0.9239
# Epoch 72/100
# 3579/3579 - 0s - loss: 0.2160 - accuracy: 0.9173 - val_loss: 0.2186 - val_accuracy: 0.9239
# Epoch 73/100
# 3579/3579 - 0s - loss: 0.2141 - accuracy: 0.9193 - val_loss: 0.2163 - val_accuracy: 0.9239
# Epoch 74/100
# 3579/3579 - 0s - loss: 0.2137 - accuracy: 0.9179 - val_loss: 0.2223 - val_accuracy: 0.9172
# Epoch 75/100
# 3579/3579 - 0s - loss: 0.2178 - accuracy: 0.9176 - val_loss: 0.2215 - val_accuracy: 0.9262
# Epoch 76/100
# 3579/3579 - 0s - loss: 0.2158 - accuracy: 0.9179 - val_loss: 0.2121 - val_accuracy: 0.9262
# Epoch 77/100
# 3579/3579 - 0s - loss: 0.2129 - accuracy: 0.9190 - val_loss: 0.2175 - val_accuracy: 0.9262
# Epoch 78/100
# 3579/3579 - 0s - loss: 0.2135 - accuracy: 0.9187 - val_loss: 0.2212 - val_accuracy: 0.9239
# Epoch 79/100
# 3579/3579 - 0s - loss: 0.2161 - accuracy: 0.9165 - val_loss: 0.2230 - val_accuracy: 0.9262
# Epoch 80/100
# 3579/3579 - 0s - loss: 0.2151 - accuracy: 0.9198 - val_loss: 0.2160 - val_accuracy: 0.9262
# Epoch 81/100
# 3579/3579 - 0s - loss: 0.2131 - accuracy: 0.9198 - val_loss: 0.2257 - val_accuracy: 0.9262
# Epoch 82/100
# 3579/3579 - 0s - loss: 0.2172 - accuracy: 0.9195 - val_loss: 0.2205 - val_accuracy: 0.9284
# Epoch 83/100
# 3579/3579 - 0s - loss: 0.2130 - accuracy: 0.9201 - val_loss: 0.2139 - val_accuracy: 0.9217
# Epoch 84/100
# 3579/3579 - 0s - loss: 0.2139 - accuracy: 0.9181 - val_loss: 0.2206 - val_accuracy: 0.9284
# Epoch 85/100
# 3579/3579 - 0s - loss: 0.2116 - accuracy: 0.9193 - val_loss: 0.2131 - val_accuracy: 0.9284
# Epoch 86/100
# 3579/3579 - 0s - loss: 0.2107 - accuracy: 0.9206 - val_loss: 0.2368 - val_accuracy: 0.9239
# Epoch 87/100
# 3579/3579 - 0s - loss: 0.2142 - accuracy: 0.9198 - val_loss: 0.2335 - val_accuracy: 0.9239
# Epoch 88/100
# 3579/3579 - 0s - loss: 0.2140 - accuracy: 0.9206 - val_loss: 0.2248 - val_accuracy: 0.9262
# Epoch 89/100
# 3579/3579 - 0s - loss: 0.2115 - accuracy: 0.9190 - val_loss: 0.2169 - val_accuracy: 0.9195
# Epoch 90/100
# 3579/3579 - 0s - loss: 0.2158 - accuracy: 0.9212 - val_loss: 0.2166 - val_accuracy: 0.9239
# Epoch 91/100
# 3579/3579 - 0s - loss: 0.2106 - accuracy: 0.9201 - val_loss: 0.2196 - val_accuracy: 0.9351
# Epoch 92/100
# 3579/3579 - 0s - loss: 0.2163 - accuracy: 0.9193 - val_loss: 0.2176 - val_accuracy: 0.9284
# Epoch 93/100
# 3579/3579 - 0s - loss: 0.2132 - accuracy: 0.9179 - val_loss: 0.2300 - val_accuracy: 0.9239
# Epoch 94/100
# 3579/3579 - 0s - loss: 0.2127 - accuracy: 0.9201 - val_loss: 0.2239 - val_accuracy: 0.9172
# Epoch 95/100
# 3579/3579 - 0s - loss: 0.2155 - accuracy: 0.9193 - val_loss: 0.2263 - val_accuracy: 0.9284
# Epoch 96/100
# 3579/3579 - 0s - loss: 0.2112 - accuracy: 0.9209 - val_loss: 0.2179 - val_accuracy: 0.9306
# Epoch 97/100
# 3579/3579 - 0s - loss: 0.2110 - accuracy: 0.9187 - val_loss: 0.2210 - val_accuracy: 0.9262
# Epoch 98/100
# 3579/3579 - 0s - loss: 0.2093 - accuracy: 0.9206 - val_loss: 0.2258 - val_accuracy: 0.9306
# Epoch 99/100
# 3579/3579 - 0s - loss: 0.2122 - accuracy: 0.9215 - val_loss: 0.2244 - val_accuracy: 0.9284
# Epoch 100/100
# 3579/3579 - 0s - loss: 0.2132 - accuracy: 0.9218 - val_loss: 0.2186 - val_accuracy: 0.9284

# %% [markdown]
# ### *** Side Note - BATCHING
# - For Batching, why didn't we do it like Mnist and used .Batch(batch_size) method. Whats the difference between that and batching when directly fitting the model?
# - train_data.batch(BATCH_SIZE) is a method of tf.data data sets. Its is the same as batching via model.fit().

# %% [markdown]
# ### *** Side Note - VALIDATION STEPS
# - Validation steps is used when validation data is a tf.data dataset. Here, validation data is just a numpy array. That's why validation steps is not required.
